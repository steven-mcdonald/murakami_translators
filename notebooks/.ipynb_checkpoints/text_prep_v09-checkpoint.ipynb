# %% [markdown]
# DDD - initial data prep
# * read in pickle
# * split into chapters
# * run several functions to chunk the text
# * all in dataframes this time compared to lists in tex_prep_v02

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1.5)

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

import textacy
import re

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
import pickle

# %%
book_dict = {'The Elephant Vanishes': 'ev_birnbaum_rubin_v01', 
             'Norwegian Wood 1': 'nw_birnbaum_v01', 
             'Norwegian Wood 2': 'nw_rubin_v01',
             'Wild Sheep Chase': 'wsc_birnbaum_v01', 
             'Wind Up Bird Chronicle': 'wubc_all_rubin_v01', 
             'Sputnik Sweetheart': 'ss_gabriel_v01',
             'Kafka on the Shore': 'kots_gabriel_v01',
             'Dance Dance Dance': 'ddd_birnbaum_v01',
             'Colorless Tsukuru Tazaki': 'ctt_gabriel_v01'}

# %%
books = pd.DataFrame.from_dict(book_dict, orient='index').reset_index()
books.columns = ['Title', 'Pickle']
books
# Out:
#                       Title                 Pickle
# 0     The Elephant Vanishes  ev_birnbaum_rubin_v01
# 1          Norwegian Wood 1        nw_birnbaum_v01
# 2          Norwegian Wood 2           nw_rubin_v01
# 3          Wild Sheep Chase       wsc_birnbaum_v01
# 4    Wind Up Bird Chronicle     wubc_all_rubin_v01
# 5        Sputnik Sweetheart         ss_gabriel_v01
# 6        Kafka on the Shore       kots_gabriel_v01
# 7         Dance Dance Dance       ddd_birnbaum_v01
# 8  Colorless Tsukuru Tazaki        ctt_gabriel_v01

# %%
def load_pickle(filename):
    in_path = '../../../../Documents/murakami/pkl/' + filename + '.pkl'
    with open (in_path, 'rb') as fp:
        return pickle.load(fp)

# %%
books['full_text'] = books['Pickle'].apply(load_pickle)

# %%
books
# Out:
#                       Title                 Pickle  \
# 0     The Elephant Vanishes  ev_birnbaum_rubin_v01
# 1          Norwegian Wood 1        nw_birnbaum_v01
# 2          Norwegian Wood 2           nw_rubin_v01
# 3          Wild Sheep Chase       wsc_birnbaum_v01
# 4    Wind Up Bird Chronicle     wubc_all_rubin_v01
# 5        Sputnik Sweetheart         ss_gabriel_v01
# 6        Kafka on the Shore       kots_gabriel_v01
# 7         Dance Dance Dance       ddd_birnbaum_v01
# 8  Colorless Tsukuru Tazaki        ctt_gabriel_v01
#
#                                            full_text
# 0  I’M IN THE kitchen cooking spaghetti when the ...
# 1  C H II P T E R 6 (rontinutd) The scene at dinn...
# 2  [Haruki Murakami Norwegian Wood This book was ...
# 3  [\n , \n \n \n , Contents \n Cover \n About th...
# 4  [1 \n Tuesday’s Wind-up Bird \n ♦ \n Six Finge...
# 5  [Haruki Murakami None This book was produced i...
# 6  [Kafka on the Shore \n Haruki Murakami \n \n \...
# 7  [\n , \n \n \n , Contents \n Cover \n About th...
# 8  [\n , \n \n \n , Contents \n Cover \n About th...

# %%
# books.iloc[0,2]

# %%
ddd = books['full_text'].iloc[7]

# %%
# wsc is read from an epub and is a list of texts
len(ddd)
# Out:
# 56

# %%
ddd[50]
# Out:
# '\n YUMIYOSHI CAME BACK  at six-thirty.  Still in uniform, although her blouse was different.  She’d brought a bag with a change of clothes and toiletries and cosmetics. \n “I don’t know,” I said.  “They’re going to find out some time.” \n “Don’t worry, I’m not careless,” she said, then smiled and draped her blazer over the back of a chair. \n Then we sat on the sofa and held each other tight. \n “I’ve thought about you all day long,” she said.  “You know, wouldn’t it be wonderful if I could work during the daytime, then sneak into your room at night?  We’d spend the night together, then in the morning I’d go straight to work?” \n “A home convenient to your workplace,” I joked.  “Unfortunately I couldn’t keep footing the tab to this room.  And sooner or later, they’ll find out about us.” \n “Nothing goes smoothly in this world.” \n “You can say that again.” \n “But it’d be okay for a few more nights, wouldn’t it?” \n “I imagine that’s what’s going to happen.” \n “Good.  I’ll be happy with those few days.  Let’s both stay in this hotel.” \n Then she undressed, neatly folding each article of clothing.  She removed her watch and her glasses, and placed them  on  the table.  Then we enjoyed an hour of lovemaking, until we were both exhausted.  No better kind of exhaustion. \n “Mmm,” was Yumiyoshi’s appraisal.  Then she snuggled up in my arms for a nap.  After a while, I got up, showered, then drank a beer.  I sat, admiring Yumiyoshi’s sleeping face.  She slept so nice. \n A little before eight, she awoke, hungry.  We ordered a sandwich and pasta au gratin from room service.  Meanwhile, she stored her things in the closet, and when the bellhop knocked, she hid in the bathroom. \n We ate happily. \n “I’ve been thinking about it all afternoon,” I began, picking up from our earlier conversation.  “There’s nothing for me in Tokyo anymore.  I could move up here and look for work.” \n “You’d live here?” \n “That’s right, I’d live here,” I said. \n “I’ll rent an apartment and start a new life here.  You can come over whenever you want to.  You can spend the night if you feel like it.  We can try it out like that for a while.  But I’ve got the feeling it’s going to work out.  It’ll bring me back to reality.  It’ll give you space to relax.  And it’ll keep us together.” \n Yumiyoshi smiled and gave me a big kiss.  “ Fan tastic!” \n “What comes later, I don’t know.  But I’ve got a good feeling about it.  Like I said.” \n “Nobody knows what’s going to happen in the future.  I’m not worried about that.  Right now, it’s just fantastic!  Oooh, the best kind of fantastic!” \n I called room service for a bucket of ice, making Yumiyoshi hide in the bathroom again.  And while she was in there, I took out the bottle of vodka and tomato juice I’d bought in town that afternoon and made us two Bloody Marys.  No lemon slices or Lea & Perrins, but bloody good enough.  We toasted.  To us.  I switched on the bedside Muzak and punched the Pops channel.  Soon we were treated to the lush strains of Mantovani playing “Strangers in the Night.”  You  didn’t hear me making snide comments. \n “You think of everything,” said Yumiyoshi.  “I was just dreaming of a Bloody Mary right about now.  How did you know?” \n “If you listen carefully, you can hear these things.  If you look carefully, you’ll see what you’re after.” \n “Words of wisdom?” \n “No, just words.  A way of life in words.” \n “You ought to specialize in inspirational writing.” \n We had three Bloody Marys each.  Then we took our clothes off and gently made love again. \n At one point, in the middle of our lovemaking, I thought I could hear that old Dolphin Hotel elevator  cr-cr-crr-creaking  up the shaft.  Yes, this place was the knot, the node.  Here’s where it all tied together and I was a part of it all.  Here was reality, I didn’t have to go further.  I was already there.  All I had to do was to recover the knot to be connected.  It’s what I’d been seeking for years.  What the Sheep Man held together ...

# %%
ddd[7][:30]
# Out:
# '\n I OFTEN DREAM  about the Dol'

# %%
ch_texts = ddd[7:51]

# %%
ch_nos = range(1,45)
ch_titles = range(1,45)

# %%
chapters = pd.DataFrame({'number': ch_nos, 'title': ch_titles, 'text': ch_texts})
chapters.head()
# Out:
#    number  title                                               text
# 0       1      1  \n I OFTEN DREAM  about the Dolphin Hotel. \n ...
# 1       2      2  \n I GOT SENT  to Hokkaido on assignment.  As ...
# 2       3      3  \n IT TAKES NO  great effort to find work in t...
# 3       4      4  \n I BOOKED A  taxi for two days, and the phot...
# 4       5      5  \n I COULDN’T STAND  around gawking at the faç...

# %%
# function to find indices of full stops in a text
def fs_indexer(x):
    return [i for i, char in enumerate(x) if char == "."]

# %%
chapters['fstop_indices'] = chapters['text'].apply(lambda x: fs_indexer(x))

# %%
chapters.head()
# Out:
#    number  title                                               text  \
# 0       1      1  \n I OFTEN DREAM  about the Dolphin Hotel. \n ...
# 1       2      2  \n I GOT SENT  to Hokkaido on assignment.  As ...
# 2       3      3  \n IT TAKES NO  great effort to find work in t...
# 3       4      4  \n I BOOKED A  taxi for two days, and the phot...
# 4       5      5  \n I COULDN’T STAND  around gawking at the faç...
#
#                                        fstop_indices
# 0  [40, 119, 182, 233, 277, 322, 360, 396, 421, 4...
# 1  [39, 121, 208, 314, 519, 605, 660, 736, 781, 8...
# 2  [95, 161, 287, 368, 407, 459, 497, 558, 596, 6...
# 3  [127, 187, 282, 299, 428, 505, 597, 723, 784, ...
# 4  [56, 145, 222, 321, 407, 502, 634, 649, 747, 8...

# %%
# function to find indices of full stops in a text
def split_indexer(text, n=1000):
    fstop_indices = fs_indexer(text)
    split_indices = []
    for j in range(n, len(text), n):
        i = 0
# keep going through the indices while less than the 1000 step
        while fstop_indices[i] < j:
            i += 1
# append list with the index of the full stop before the 1000 step
        split_indices.append(fstop_indices[i-1])
    return split_indices

# %%
chapters['split_indices'] = chapters['text'].apply(lambda x: split_indexer(x))

# %%
chapters.head()
# Out:
#    number  title                                               text  \
# 0       1      1  \n I OFTEN DREAM  about the Dolphin Hotel. \n ...
# 1       2      2  \n I GOT SENT  to Hokkaido on assignment.  As ...
# 2       3      3  \n IT TAKES NO  great effort to find work in t...
# 3       4      4  \n I BOOKED A  taxi for two days, and the phot...
# 4       5      5  \n I COULDN’T STAND  around gawking at the faç...
#
#                                        fstop_indices  \
# 0  [40, 119, 182, 233, 277, 322, 360, 396, 421, 4...
# 1  [39, 121, 208, 314, 519, 605, 660, 736, 781, 8...
# 2  [95, 161, 287, 368, 407, 459, 497, 558, 596, 6...
# 3  [127, 187, 282, 299, 428, 505, 597, 723, 784, ...
# 4  [56, 145, 222, 321, 407, 502, 634, 649, 747, 8...
#
#                                        split_indices
# 0  [881, 1974, 2990, 3882, 4988, 5962, 6982, 7990...
# 1          [995, 1977, 2983, 3986, 4999, 5949, 6950]
# 2    [945, 1969, 2946, 3985, 4976, 5994, 6958, 7840]
# 3  [979, 1960, 2993, 3999, 4943, 5959, 6979, 7964...
# 4  [877, 1975, 2889, 3971, 4904, 5992, 6983, 7952...

# %%
# function to chunk a text
def text_chunker(text):
    split_indices = split_indexer(text)
    chunks = []
    for i, idx in enumerate(split_indices):
# if first split then start at index 0 and keep up to the full stop index (including the full stop)
        if i == 0:
            chunks.append(text[0:idx+1])
# else start from the end of the previous chunk after the full stop until the next
        else:
            chunks.append(text[split_indices[i-1]+2:idx+1])
    return chunks

# %%
chapters['chunks'] = chapters['text'].apply(lambda x: text_chunker(x))

# %%
chapters.head()
# Out:
#    number  title                                               text  \
# 0       1      1  \n I OFTEN DREAM  about the Dolphin Hotel. \n ...
# 1       2      2  \n I GOT SENT  to Hokkaido on assignment.  As ...
# 2       3      3  \n IT TAKES NO  great effort to find work in t...
# 3       4      4  \n I BOOKED A  taxi for two days, and the phot...
# 4       5      5  \n I COULDN’T STAND  around gawking at the faç...
#
#                                        fstop_indices  \
# 0  [40, 119, 182, 233, 277, 322, 360, 396, 421, 4...
# 1  [39, 121, 208, 314, 519, 605, 660, 736, 781, 8...
# 2  [95, 161, 287, 368, 407, 459, 497, 558, 596, 6...
# 3  [127, 187, 282, 299, 428, 505, 597, 723, 784, ...
# 4  [56, 145, 222, 321, 407, 502, 634, 649, 747, 8...
#
#                                        split_indices  \
# 0  [881, 1974, 2990, 3882, 4988, 5962, 6982, 7990...
# 1          [995, 1977, 2983, 3986, 4999, 5949, 6950]
# 2    [945, 1969, 2946, 3985, 4976, 5994, 6958, 7840]
# 3  [979, 1960, 2993, 3999, 4943, 5959, 6979, 7964...
# 4  [877, 1975, 2889, 3971, 4904, 5992, 6983, 7952...
#
#                                               chunks
# 0  [\n I OFTEN DREAM  about the Dolphin Hotel. \n...
# 1  [\n I GOT SENT  to Hokkaido on assignment.  As...
# 2  [\n IT TAKES NO  great effort to find work in ...
# 3  [\n I BOOKED A  taxi for two days, and the pho...
# 4  [\n I COULDN’T STAND  around gawking at the fa...

# %%
lengths = []
for chapter in chapters['chunks']:
    for chunk in chapter:
        lengths.append(len(chunk))
plt.hist(lengths, bins=20);

# %%
len(lengths)
# Out:
# 650

# %%
chapters['translator'] = 'Alfred Birnbaum'

# %%
chapters['book_title'] = 'Dance Dance Dance'

# %%
chapters.head()
# Out:
#    number  title                                               text  \
# 0       1      1  \n I OFTEN DREAM  about the Dolphin Hotel. \n ...
# 1       2      2  \n I GOT SENT  to Hokkaido on assignment.  As ...
# 2       3      3  \n IT TAKES NO  great effort to find work in t...
# 3       4      4  \n I BOOKED A  taxi for two days, and the phot...
# 4       5      5  \n I COULDN’T STAND  around gawking at the faç...
#
#                                        fstop_indices  \
# 0  [40, 119, 182, 233, 277, 322, 360, 396, 421, 4...
# 1  [39, 121, 208, 314, 519, 605, 660, 736, 781, 8...
# 2  [95, 161, 287, 368, 407, 459, 497, 558, 596, 6...
# 3  [127, 187, 282, 299, 428, 505, 597, 723, 784, ...
# 4  [56, 145, 222, 321, 407, 502, 634, 649, 747, 8...
#
#                                        split_indices  \
# 0  [881, 1974, 2990, 3882, 4988, 5962, 6982, 7990...
# 1          [995, 1977, 2983, 3986, 4999, 5949, 6950]
# 2    [945, 1969, 2946, 3985, 4976, 5994, 6958, 7840]
# 3  [979, 1960, 2993, 3999, 4943, 5959, 6979, 7964...
# 4  [877, 1975, 2889, 3971, 4904, 5992, 6983, 7952...
#
#                                               chunks       translator  \
# 0  [\n I OFTEN DREAM  about the Dolphin Hotel. \n...  Alfred Birnbaum
# 1  [\n I GOT SENT  to Hokkaido on assignment.  As...  Alfred Birnbaum
# 2  [\n IT TAKES NO  great effort to find work in ...  Alfred Birnbaum
# 3  [\n I BOOKED A  taxi for two days, and the pho...  Alfred Birnbaum
# 4  [\n I COULDN’T STAND  around gawking at the fa...  Alfred Birnbaum
#
#           book_title
# 0  Dance Dance Dance
# 1  Dance Dance Dance
# 2  Dance Dance Dance
# 3  Dance Dance Dance
# 4  Dance Dance Dance

# %%
out_path = '../../../../Documents/murakami/pkl2/'
out_name = 'ddd_birnbaum_v01'
out_full_path = out_path + out_name + '.pkl'

# %%
# save pickle
with open(out_full_path, 'wb') as fp:
    pickle.dump(chapters, fp)


# read back pickle
with open (out_full_path, 'rb') as fp:
    read_ddd = pickle.load(fp)

# %%
read_ddd
# Out:
#     number  title                                               text  \
# 0        1      1  \n I OFTEN DREAM  about the Dolphin Hotel. \n ...
# 1        2      2  \n I GOT SENT  to Hokkaido on assignment.  As ...
# 2        3      3  \n IT TAKES NO  great effort to find work in t...
# 3        4      4  \n I BOOKED A  taxi for two days, and the phot...
# 4        5      5  \n I COULDN’T STAND  around gawking at the faç...
# 5        6      6  \n I PUTTERED AROUND  in the hotel, seeing wha...
# 6        7      7  \n THERE WAS NOTHING  for me to do.  Nothing I...
# 7        8      8  \n FROM MY ROOM  I rang up my ex-partner in To...
# 8        9      9  \n BY ELEVEN O’CLOCK  that night I was out of ...
# 9       10     10  \n THE DARKNESS WAS  deathly absolute. \n I co...
# 10      11     11  \n WE FACED EACH  other across a small table, ...
# 11      12     12  \n BACK IN MY  room, I ran a bath.  I undresse...
# 12      13     13  \n KNOTS . \n It was nine  P.M .  I was eating...
# 13      14     14  \n STRANGELY ENOUGH—BUT  not that strangely, I...
# 14      15     15  \n I SANK BACK  into my seat, folded my hands ...
# 15      16     16  \n AFTER COLLECTING OUR  bags at Haneda, Yuki ...
# 16      17     17  \n I LEANED UP  against the sink in the kitche...
# 17      18     18  \n “WELL, BEEN A  long time.” \n Gotanda’s voi...
# 18      19     19  \n THEN WE RODE  in the Mercedes to a bar down...
# 19      20     20  \n THE NEXT FEW  days passed uneventfully.  Th...
# 20      21     21  \n THEY SHOWED UP  a little past three in the ...
# 21      22     22  \n THE NEXT DAY  wasn’t much different than th...
# 22      23     23  \n THE TWO DETECTIVES  came back into the room...
# 23      24     24  \n BY THE TIME  we reached Yuki’s father’s hou...
# 24      25     25  \n AT SEVEN O’CLOCK , Yuki came sauntering bac...
# 25      26     26  \n IT WAS TWELVE-THIRTY  when Gotanda called. ...
# 26      27     27  \n A WEEK PASSED .  Spring made solid advances...
# 27      28     28  \n NEXT ON THE  news .  I lay on the beach at ...
# 28      29     29  \n THE FOLLOWING MORNING , Yuki said she wante...
# 29      30     30  \n HAWAII . \n The next few days were bliss.  ...
# 30      31     31  \n BACK AT THE  Shibuya apartment, I went thro...
# 31      32     32  \n GOTANDA SWUNG BY  at eight-forty.  He was w...
# 32      33     33  \n THE FOLLOWING MORNING , I went to check on ...
# 33      34     34  \n DICK NORTH HAD  been doing the shopping on ...
# 34      35     35  \n TOWARD THE END  of May, by chance—as far as...
# 35      36     36  \n MAY DRIFTED PAST , slow as clouds. \n It ha...
# 36      37     37  \n I WENT UP  to see Yuki a few more times.  T...
# 37      38     38  \n I SAT YUKI  in the front seat and wound her...
# 38      39     39  \n I TRIED TO  put my thoughts in order. \n Fi...
# 39      40     40  \n THE FOLLOWING AFTERNOON  they dredged the M...
# 40      41     41  \n THREE DAYS AFTER  Gotanda plowed the Masera...
# 41      42     42  \n I HAD A  dream about Kiki.  I guess it was ...
# 42      43     43  \n WHEN I GOT  back to the Dolphin Hotel, thre...
# 43      44     44  \n YUMIYOSHI CAME BACK  at six-thirty.  Still ...
#
#                                         fstop_indices  \
# 0   [40, 119, 182, 233, 277, 322, 360, 396, 421, 4...
# 1   [39, 121, 208, 314, 519, 605, 660, 736, 781, 8...
# 2   [95, 161, 287, 368, 407, 459, 497, 558, 596, 6...
# 3   [127, 187, 282, 299, 428, 505, 597, 723, 784, ...
# 4   [56, 145, 222, 321, 407, 502, 634, 649, 747, 8...
# 5   [63, 225, 326, 361, 407, 459, 522, 619, 730, 7...
# 6   [33, 83, 205, 340, 428, 515, 562, 629, 671, 73...
# 7   [48, 211, 228, 276, 373, 411, 492, 553, 634, 6...
# 8   [57, 91, 174, 239, 261, 356, 449, 522, 622, 70...
# 9   [36, 83, 113, 165, 197, 230, 279, 300, 380, 40...
# 10  [52, 119, 170, 233, 260, 287, 318, 340, 441, 5...
# 11  [32, 67, 104, 175, 304, 445, 525, 566, 609, 70...
# 12  [8, 26, 29, 101, 166, 223, 272, 324, 375, 420,...
# 13  [112, 159, 207, 234, 307, 380, 421, 506, 549, ...
# 14  [125, 198, 230, 280, 330, 352, 441, 484, 581, ...
# 15  [68, 78, 117, 248, 359, 413, 432, 453, 530, 55...
# 16  [69, 190, 215, 253, 329, 368, 397, 453, 494, 5...
# 17  [26, 76, 105, 134, 172, 190, 226, 287, 373, 62...
# 18  [68, 136, 246, 267, 306, 340, 393, 437, 465, 5...
# 19  [40, 138, 199, 272, 354, 384, 418, 524, 596, 7...
# 20  [54, 111, 166, 205, 248, 298, 457, 521, 592, 6...
# 21  [55, 170, 242, 326, 358, 388, 432, 519, 589, 6...
# 22  [81, 99, 159, 190, 213, 256, 304, 341, 361, 37...
# 23  [75, 134, 191, 242, 322, 430, 475, 595, 624, 7...
# 24  [46, 80, 133, 157, 223, 271, 389, 414, 580, 63...
# 25  [43, 70, 198, 252, 303, 324, 424, 504, 528, 54...
# 26  [16, 67, 93, 166, 219, 240, 302, 325, 364, 388...
# 27  [20, 147, 169, 242, 323, 402, 456, 603, 664, 6...
# 28  [67, 129, 185, 272, 377, 456, 504, 547, 615, 6...
# 29  [9, 41, 62, 156, 180, 263, 299, 372, 420, 486,...
# 30  [69, 122, 273, 323, 362, 424, 523, 542, 572, 6...
# 31  [34, 190, 221, 242, 295, 331, 411, 457, 519, 6...
# 32  [57, 89, 156, 233, 316, 389, 416, 454, 499, 55...
# 33  [218, 339, 382, 465, 576, 644, 713, 814, 834, ...
# 34  [115, 125, 280, 386, 438, 481, 580, 643, 678, ...
# 35  [35, 89, 126, 172, 252, 286, 341, 388, 434, 54...
# 36  [41, 68, 176, 232, 286, 344, 411, 462, 544, 62...
# 37  [57, 145, 175, 263, 334, 360, 476, 544, 627, 7...
# 38  [38, 201, 233, 310, 336, 429, 468, 527, 602, 7...
# 39  [69, 85, 100, 145, 163, 213, 220, 237, 331, 36...
# 40  [74, 165, 197, 207, 281, 330, 370, 401, 426, 5...
# 41  [27, 52, 95, 167, 196, 304, 356, 409, 462, 504...
# 42  [95, 179, 209, 240, 257, 298, 421, 552, 599, 6...
# 43  [36, 90, 166, 192, 231, 337, 390, 441, 678, 74...
#
#                                         split_indices  \
# 0   [881, 1974, 2990, 3882, 4988, 5962, 6982, 7990...
# 1           [995, 1977, 2983, 3986, 4999, 5949, 6950]
# 2     [945, 1969, 2946, 3985, 4976, 5994, 6958, 7840]
# 3   [979, 1960, 2993, 3999, 4943, 5959, 6979, 7964...
# 4   [877, 1975, 2889, 3971, 4904, 5992, 6983, 7952...
# 5   [934, 1757, 2928, 3923, 4977, 5860, 6897, 7996...
# 6   [906, 1955, 2947, 3991, 4913, 5950, 6905, 7973...
# 7   [965, 1993, 2965, 3967, 4995, 5996, 6994, 7986...
# 8           [972, 1972, 2962, 3971, 4908, 5925, 6974]
# 9   [987, 1949, 2987, 3983, 4984, 5976, 6856, 7928...
# 10  [955, 1965, 2998, 3982, 4936, 5987, 6979, 7988...
# 11    [958, 1988, 2982, 3990, 4948, 5966, 6972, 7990]
# 12                            [979, 1957, 2977, 3998]
# 13  [953, 1882, 2989, 3974, 4974, 5928, 6996, 7903...
# 14  [962, 1965, 2998, 3946, 4984, 5993, 6939, 7972...
# 15  [930, 1986, 2984, 3971, 4958, 5993, 6937, 7931...
# 16  [962, 1972, 2987, 3973, 4897, 5993, 6968, 7995...
# 17  [971, 1966, 2958, 3958, 4946, 5995, 6946, 7999...
# 18  [954, 1993, 2937, 3963, 4971, 5987, 6975, 7998...
# 19    [939, 1920, 2945, 3849, 4955, 5976, 6949, 7955]
# 20  [941, 1922, 2915, 3963, 4986, 5922, 6990, 7947...
# 21  [936, 1966, 2946, 3953, 4968, 5977, 6995, 7980...
# 22  [998, 1986, 2955, 3972, 4984, 5958, 6973, 7935...
# 23  [973, 1984, 2980, 3986, 4992, 5994, 6954, 7983...
# 24  [942, 1970, 2897, 3966, 4984, 5997, 6993, 7937...
# 25  [994, 1942, 2988, 3917, 4977, 5975, 6974, 7993...
# 26  [923, 1966, 2968, 3994, 4974, 5974, 6948, 7993...
# 27                      [979, 1991, 2973, 3910, 4992]
# 28  [935, 1960, 2911, 3949, 4968, 5924, 6958, 7979...
# 29  [975, 1976, 2962, 3973, 4926, 5973, 6976, 7970...
# 30  [987, 1960, 2900, 3960, 4928, 5978, 6938, 7918...
# 31  [978, 1989, 2968, 3988, 4925, 5929, 6999, 7956...
# 32  [959, 1940, 2993, 3961, 4980, 5994, 6957, 7950...
# 33  [967, 1992, 2991, 3953, 4951, 5990, 6947, 7994...
# 34  [950, 1978, 2967, 3992, 4978, 5966, 6988, 7956...
# 35          [940, 1976, 2990, 3968, 4976, 5905, 6933]
# 36    [997, 1948, 2953, 3963, 4807, 5947, 6991, 7955]
# 37  [957, 1932, 2985, 3976, 4997, 5967, 6940, 7934...
# 38  [993, 1972, 2985, 3516, 4972, 5916, 6913, 7983...
# 39                                  [962, 1974, 2967]
# 40    [978, 1954, 2992, 3985, 4977, 5999, 6989, 7965]
# 41          [981, 1991, 2974, 3965, 4963, 5974, 6970]
# 42  [960, 1981, 2966, 3958, 4953, 5981, 6975, 7983...
# 43  [970, 1947, 2948, 3969, 4977, 5916, 6989, 7981...
#
#                                                chunks       translator  \
# 0   [\n I OFTEN DREAM  about the Dolphin Hotel. \n...  Alfred Birnbaum
# 1   [\n I GOT SENT  to Hokkaido on assignment.  As...  Alfred Birnbaum
# 2   [\n IT TAKES NO  great effort to find work in ...  Alfred Birnbaum
# 3   [\n I BOOKED A  taxi for two days, and the pho...  Alfred Birnbaum
# 4   [\n I COULDN’T STAND  around gawking at the fa...  Alfred Birnbaum
# 5   [\n I PUTTERED AROUND  in the hotel, seeing wh...  Alfred Birnbaum
# 6   [\n THERE WAS NOTHING  for me to do.  Nothing ...  Alfred Birnbaum
# 7   [\n FROM MY ROOM  I rang up my ex-partner in T...  Alfred Birnbaum
# 8   [\n BY ELEVEN O’CLOCK  that night I was out of...  Alfred Birnbaum
# 9   [\n THE DARKNESS WAS  deathly absolute. \n I c...  Alfred Birnbaum
# 10  [\n WE FACED EACH  other across a small table,...  Alfred Birnbaum
# 11  [\n BACK IN MY  room, I ran a bath.  I undress...  Alfred Birnbaum
# 12  [\n KNOTS . \n It was nine  P.M .  I was eatin...  Alfred Birnbaum
# 13  [\n STRANGELY ENOUGH—BUT  not that strangely, ...  Alfred Birnbaum
# 14  [\n I SANK BACK  into my seat, folded my hands...  Alfred Birnbaum
# 15  [\n AFTER COLLECTING OUR  bags at Haneda, Yuki...  Alfred Birnbaum
# 16  [\n I LEANED UP  against the sink in the kitch...  Alfred Birnbaum
# 17  [\n “WELL, BEEN A  long time.” \n Gotanda’s vo...  Alfred Birnbaum
# 18  [\n THEN WE RODE  in the Mercedes to a bar dow...  Alfred Birnbaum
# 19  [\n THE NEXT FEW  days passed uneventfully.  T...  Alfred Birnbaum
# 20  [\n THEY SHOWED UP  a little past three in the...  Alfred Birnbaum
# 21  [\n THE NEXT DAY  wasn’t much different than t...  Alfred Birnbaum
# 22  [\n THE TWO DETECTIVES  came back into the roo...  Alfred Birnbaum
# 23  [\n BY THE TIME  we reached Yuki’s father’s ho...  Alfred Birnbaum
# 24  [\n AT SEVEN O’CLOCK , Yuki came sauntering ba...  Alfred Birnbaum
# 25  [\n IT WAS TWELVE-THIRTY  when Gotanda called....  Alfred Birnbaum
# 26  [\n A WEEK PASSED .  Spring made solid advance...  Alfred Birnbaum
# 27  [\n NEXT ON THE  news .  I lay on the beach at...  Alfred Birnbaum
# 28  [\n THE FOLLOWING MORNING , Yuki said she want...  Alfred Birnbaum
# 29  [\n HAWAII . \n The next few days were bliss. ...  Alfred Birnbaum
# 30  [\n BACK AT THE  Shibuya apartment, I went thr...  Alfred Birnbaum
# 31  [\n GOTANDA SWUNG BY  at eight-forty.  He was ...  Alfred Birnbaum
# 32  [\n THE FOLLOWING MORNING , I went to check on...  Alfred Birnbaum
# 33  [\n DICK NORTH HAD  been doing the shopping on...  Alfred Birnbaum
# 34  [\n TOWARD THE END  of May, by chance—as far a...  Alfred Birnbaum
# 35  [\n MAY DRIFTED PAST , slow as clouds. \n It h...  Alfred Birnbaum
# 36  [\n I WENT UP  to see Yuki a few more times.  ...  Alfred Birnbaum
# 37  [\n I SAT YUKI  in the front seat and wound he...  Alfred Birnbaum
# 38  [\n I TRIED TO  put my thoughts in order. \n F...  Alfred Birnbaum
# 39  [\n THE FOLLOWING AFTERNOON  they dredged the ...  Alfred Birnbaum
# 40  [\n THREE DAYS AFTER  Gotanda plowed the Maser...  Alfred Birnbaum
# 41  [\n I HAD A  dream about Kiki.  I guess it was...  Alfred Birnbaum
# 42  [\n WHEN I GOT  back to the Dolphin Hotel, thr...  Alfred Birnbaum
# 43  [\n YUMIYOSHI CAME BACK  at six-thirty.  Still...  Alfred Birnbaum
#
#            book_title
# 0   Dance Dance Dance
# 1   Dance Dance Dance
# 2   Dance Dance Dance
# 3   Dance Dance Dance
# 4   Dance Dance Dance
# 5   Dance Dance Dance
# 6   Dance Dance Dance
# 7   Dance Dance Dance
# 8   Dance Dance Dance
# 9   Dance Dance Dance
# 10  Dance Dance Dance
# 11  Dance Dance Dance
# 12  Dance Dance Dance
# 13  Dance Dance Dance
# 14  Dance Dance Dance
# 15  Dance Dance Dance
# 16  Dance Dance Dance
# 17  Dance Dance Dance
# 18  Dance Dance Dance
# 19  Dance Dance Dance
# 20  Dance Dance Dance
# 21  Dance Dance Dance
# 22  Dance Dance Dance
# 23  Dance Dance Dance
# 24  Dance Dance Dance
# 25  Dance Dance Dance
# 26  Dance Dance Dance
# 27  Dance Dance Dance
# 28  Dance Dance Dance
# 29  Dance Dance Dance
# 30  Dance Dance Dance
# 31  Dance Dance Dance
# 32  Dance Dance Dance
# 33  Dance Dance Dance
# 34  Dance Dance Dance
# 35  Dance Dance Dance
# 36  Dance Dance Dance
# 37  Dance Dance Dance
# 38  Dance Dance Dance
# 39  Dance Dance Dance
# 40  Dance Dance Dance
# 41  Dance Dance Dance
# 42  Dance Dance Dance
# 43  Dance Dance Dance
